# %% [markdown]
# # Rossmann 数据探索性分析

# %% [markdown]
# ## 导入数据与库

# %%
#导入需要使用的库
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

# %%
#使用pandas读取数据
train = pd.read_csv("inputs/train.csv")
test = pd.read_csv("inputs/test.csv")
store = pd.read_csv("inputs/store.csv")
# Out:
# /Users/limao/miniconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#查看train数据的前五行
train.head(5)
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %% [markdown]
# ## 数据清洗

# %%
#查看train中每个特征的unique值
feature_list = train.columns.values.tolist()
for feature in feature_list:
    print('{} 唯一值数量:'.format(feature),len(train[feature].unique()))
# Out:
# Store 唯一值数量: 1115
# DayOfWeek 唯一值数量: 7
# Date 唯一值数量: 942
# Sales 唯一值数量: 21734
# Customers 唯一值数量: 4086
# Open 唯一值数量: 2
# Promo 唯一值数量: 2
# StateHoliday 唯一值数量: 5
# SchoolHoliday 唯一值数量: 2

# %%
#unique值检查中发现StateHoliday有异常.检查发现是有把数字0和字符‘0’混淆
train.StateHoliday.unique()
# Out:
# array(['0', 'a', 'b', 'c', 0], dtype=object)

# %%
#检查train数据集是否有空缺值
train.isnull().any(axis=0)
# Out:
# Store            False
# DayOfWeek        False
# Date             False
# Sales            False
# Customers        False
# Open             False
# Promo            False
# StateHoliday     False
# SchoolHoliday    False
# dtype: bool

# %%
#打印train训练集的信息
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
# Store            1017209 non-null int64
# DayOfWeek        1017209 non-null int64
# Date             1017209 non-null object
# Sales            1017209 non-null int64
# Customers        1017209 non-null int64
# Open             1017209 non-null int64
# Promo            1017209 non-null int64
# StateHoliday     1017209 non-null object
# SchoolHoliday    1017209 non-null int64
# dtypes: int64(7), object(2)
# memory usage: 69.8+ MB

# %%
#查看store数据集的前五行
store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %%
for column in store:
    print('{} 的唯一值:'.format(column),len(store[column].unique()))
# Out:
# Store 的唯一值: 1115
# StoreType 的唯一值: 4
# Assortment 的唯一值: 3
# CompetitionDistance 的唯一值: 655
# CompetitionOpenSinceMonth 的唯一值: 13
# CompetitionOpenSinceYear 的唯一值: 24
# Promo2 的唯一值: 2
# Promo2SinceWeek 的唯一值: 25
# Promo2SinceYear 的唯一值: 8
# PromoInterval 的唯一值: 4

# %%
#CompetitionOpenSinceMonth 有13个unique值，检查发现是有nan，应该代表具体月份不详
store.CompetitionOpenSinceMonth.unique()
# Out:
# array([ 9., 11., 12.,  4., 10.,  8., nan,  3.,  6.,  5.,  1.,  2.,  7.])

# %%
#PromoInterval 只有 4个unique值，查看一下
store.PromoInterval.unique()
# Out:
# array([nan, 'Jan,Apr,Jul,Oct', 'Feb,May,Aug,Nov', 'Mar,Jun,Sept,Dec'],
#       dtype=object)

# %%
#检查store数据集是否有空缺值.发现CompetitionDistance等列有空缺值，分析应该是表示该行的Store没有竞争对手，所以含有competition三列为NaN
#Promo2为0情况下，自然Promo2SinceWeek/Year列为NaN
store.isnull().any(axis=0)
# Out:
# Store                        False
# StoreType                    False
# Assortment                   False
# CompetitionDistance           True
# CompetitionOpenSinceMonth     True
# CompetitionOpenSinceYear      True
# Promo2                       False
# Promo2SinceWeek               True
# Promo2SinceYear               True
# PromoInterval                 True
# dtype: bool

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
# Store                        1115 non-null int64
# StoreType                    1115 non-null object
# Assortment                   1115 non-null object
# CompetitionDistance          1112 non-null float64
# CompetitionOpenSinceMonth    761 non-null float64
# CompetitionOpenSinceYear     761 non-null float64
# Promo2                       1115 non-null int64
# Promo2SinceWeek              571 non-null float64
# Promo2SinceYear              571 non-null float64
# PromoInterval                571 non-null object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB

# %%
test.head()
# Out:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0

# %%
for feature in test:
    print('{} 唯一值数量:'.format(feature),len(test[feature].unique()))
# Out:
# Id 唯一值数量: 41088
# Store 唯一值数量: 856
# DayOfWeek 唯一值数量: 7
# Date 唯一值数量: 48
# Open 唯一值数量: 3
# Promo 唯一值数量: 2
# StateHoliday 唯一值数量: 2
# SchoolHoliday 唯一值数量: 2

# %%
#test 中open的数量为3，检查发现有NaN
test.Open.unique()
# Out:
# array([ 1., nan,  0.])

# %%
#检查test中空缺值
test.isnull().any(axis=0)
# Out:
# Id               False
# Store            False
# DayOfWeek        False
# Date             False
# Open              True
# Promo            False
# StateHoliday     False
# SchoolHoliday    False
# dtype: bool

# %% [markdown]
# ## 对空缺值做处理

# %%
#store中的NaN用0填充
store.fillna(0,inplace = True)

#test中的NaN用1填充。一定要营业的商店才有预测的意义
test.fillna(1,inplace = True)

# %%
#考察最重要的sales/customers分布
fig, (axis1, axis2) = plt.subplots(1, 2, figsize=(16, 9))

train['Sales'].plot(kind='hist', bins=50, ax=axis1,title='Sales Histgram')
train['Customers'].plot(kind='hist', bins=50, ax=axis2, title='Customers Histgram')

# %%
#观察到customer/sales都有为0的情况，如果商店开门销售额为0，则认为是异常值

train[(train['Open']==1)&(train['Sales']==0)]
# Out:
#         Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 86825     971          5  2015-05-15      0          0     1      0
# 142278    674          4  2015-03-26      0          0     1      0
# 196938    699          4  2015-02-05      0          0     1      1
# 322053    708          3  2014-10-01      0          0     1      1
# 330176    357          1  2014-09-22      0          0     1      0
# 340348    227          4  2014-09-11      0          0     1      0
# 340860    835          4  2014-09-11      0          0     1      0
# 341795    835          3  2014-09-10      0          0     1      0
# 346232    548          5  2014-09-05      0          0     1      1
# 346734     28          4  2014-09-04      0          0     1      1
# 347669     28          3  2014-09-03      0          0     1      1
# 348604     28          2  2014-09-02      0          0     1      1
# 386065    102          4  2014-07-24      0          0     1      0
# ...

# %%
#一周每天的sales、customer平均值分布，可以看到星期天平均值明显较低，是因为星期天很多商店不开门

sns.set_style("whitegrid")

fig, (axis1, axis2) = plt.subplots(1, 2, figsize=(16, 9))
sns.pointplot(x="DayOfWeek", y="Sales", data=train, order=[1, 2, 3, 4, 5, 6, 7], ax=axis1)
axis1.set_title("Average Sales per Day")

sns.pointplot(x="DayOfWeek", y="Customers", data=train, order=[1, 2, 3, 4, 5, 6, 7], ax=axis2)
axis2.set_title("Average Customers per Day")
# Out:
# Text(0.5,1,'Average Customers per Day')

# %%
#去除异常值outliner

train = train.loc[train['Sales']>0]

# %%
#只考察开门商店的平均值分布,反而可以看到周日只要是开门的商店，customer、sales都比较高
sns.set_style("whitegrid")

fig, (axis1, axis2) = plt.subplots(1, 2, figsize=(16, 9))
sns.pointplot(x="DayOfWeek", y="Sales", data=train[train['Open']==1], order=[1, 2, 3, 4, 5, 6, 7], ax=axis1)
axis1.set_title("Average Sales per Day for Open Shops")

sns.pointplot(x="DayOfWeek", y="Customers", data=train[train['Open']==1], order=[1, 2, 3, 4, 5, 6, 7], ax=axis2)
axis2.set_title("Average Customers per Day for Open Shops")
# Out:
# Text(0.5,1,'Average Customers per Day for Open Shops')

# %%
#查看销售额销售额的月度分布,很明显每年的11-12月都是销售的高峰时期

train.Date = pd.to_datetime(train.Date)

sns.set_style("whitegrid")
fig, axis = plt.subplots(1, 1, figsize=(16, 9))
axis.set_title("Average Sales per Month")

sns.pointplot(x="Date", y="Sales", data=train.groupby('Date')['Sales'].mean().resample('M',kind ='period').mean().reset_index(), ax=axis)

# %%
#查看每个商店年度销售量总和的分布，绝大多数商店年销售额在250-750万美元之间

sns.distplot(train.groupby('Store')['Sales'].sum())
plt.title('Sum of Sales per year')
plt.xlabel('Sales')
# Out:
# Text(0.5,0,'Sales')

# %% [markdown]
# ## 将 train 与 store 数据表合并

# %%
#以Store为关键字合并

train_comb = pd.merge(train,store,on ='Store',how = 'left')

#将日期数据转换为时间类型

train_comb.Date = pd.to_datetime(train_comb.Date)

#打印查看数据
train_comb.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      2          5 2015-07-31   6064        625     1      1            0
# 2      3          5 2015-07-31   8314        821     1      1            0
# 3      4          5 2015-07-31  13995       1498     1      1            0
# 4      5          5 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         a          a                570.0
# 2              1         a          a              14130.0
# 3              1         c          c                620.0
# 4              1         a          a              29910.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# ...

# %%
# 以一天时间尺度来分析，完全观察不出规律。问题本身是时间序列预测问题

fig, axis = plt.subplots(1, 1, figsize=(16, 9))
axis.set_title("Daily Sales")

sns.pointplot(x="Date", y="Sales", data=train.groupby('Date')['Sales'].mean().resample('D',kind ='period').sum().reset_index(), ax=axis)

# %% [markdown]
# ### 探索销售量与时间月份的关系

# %%
#考察不同年份见每月的销售量
#先将date分离成年月日

train_comb['year'] = train_comb.Date.map(lambda x:x.year)
train_comb['month'] = train_comb.Date.map(lambda x:x.month)
train_comb['day'] = train_comb.Date.map(lambda x:x.day)

train_comb.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      2          5 2015-07-31   6064        625     1      1            0
# 2      3          5 2015-07-31   8314        821     1      1            0
# 3      4          5 2015-07-31  13995       1498     1      1            0
# 4      5          5 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday StoreType ...  CompetitionDistance  \
# 0              1         c ...               1270.0
# 1              1         a ...                570.0
# 2              1         a ...              14130.0
# 3              1         c ...                620.0
# 4              1         a ...              29910.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# 1                       11.0                    2007.0       1
# ...

# %%
#分年的月度销售量分布图,也可以看到每年11-12月销售量快速增长

sns.set_style("whitegrid")
fig, axis = plt.subplots(1, 1, figsize=(16, 9))
axis.set_title("Monthly Sales")

sns.pointplot(x="month", y="Sales", data=train.groupby([train_comb.year,train_comb.month]).mean().reset_index(),hue='year', ax=axis)

# %%
#分年的顾客数量分布图,与销售量类似分布，每年5-6月顾客数量最少

sns.set_style("whitegrid")
fig, axis = plt.subplots(1, 1, figsize=(16, 9))
axis.set_title("Monthly Customers")

sns.pointplot(x="month", y="Customers", data=train.groupby([train_comb.year,train_comb.month]).mean().reset_index(),hue='year', ax=axis)

# %% [markdown]
# ### 选取一个月的时间窗观察月内每天平均销量变化

# %%
train_comb['month'].head()
# Out:
# 0    7
# 1    7
# 2    7
# 3    7
# 4    7
# Name: month, dtype: int64

# %%
#筛选出2月的data
feb = train_comb[train_comb['month']==1]

# %%
feb.head()
# Out:
#         Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 167266      1          6 2015-01-31   5363        638     1      0
# 167267      2          6 2015-01-31   3067        323     1      0
# 167268      3          6 2015-01-31   4382        484     1      0
# 167269      4          6 2015-01-31  11904       1560     1      0
# 167270      5          6 2015-01-31   2110        228     1      0
#
#        StateHoliday  SchoolHoliday StoreType ...  CompetitionDistance  \
# 167266            0              0         c ...               1270.0
# 167267            0              0         a ...                570.0
# 167268            0              0         a ...              14130.0
# 167269            0              0         c ...                620.0
# 167270            0              0         a ...              29910.0
#
#         CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 167266                        9.0                    2008.0       0
# ...

# %%
feb.month
# Out:
# 167266    1
# 167267    1
# 167268    1
# 167269    1
# 167270    1
# 167271    1
# 167272    1
# 167273    1
# 167274    1
# 167275    1
# 167276    1
# 167277    1
# 167278    1
# 167279    1
# 167280    1
# 167281    1
# 167282    1
# 167283    1
# 167284    1
# 167285    1
# 167286    1
# 167287    1
# 167288    1
# 167289    1
# 167290    1
# 167291    1
# 167292    1
# 167293    1
# 167294    1
# 167295    1
#          ..
# 844308    1
# 844309    1
# 844310    1
# 844311    1
# 844312    1
# 844313    1
# 844314    1
# 844315    1
# 844316    1
# 844317    1
# 844318    1
# 844319    1
# 844320    1
# 844321    1
# 844322    1
# 844323    1
# 844324    1
# 844325    1
# 844326    1
# 844327    1
# 844328    1
# 844329    1
# 844330    1
# 844331    1
# 844332    1
# 844333    1
# 844334    1
# 844335    1
# 844336    1
# 844337    1
# Name: month, Length: 86335, dtype: int64

# %%
sns.set_style("whitegrid")
fig, axis = plt.subplots(1, 1, figsize=(16, 9))
axis.set_title("Daily Sales in January")

sns.pointplot(x="day", y="Sales", data=feb.groupby('day')['Sales'].mean().reset_index(), ax=axis)

# %%
feb['year']
# Out:
# 167266    2015
# 167267    2015
# 167268    2015
# 167269    2015
# 167270    2015
# 167271    2015
# 167272    2015
# 167273    2015
# 167274    2015
# 167275    2015
# 167276    2015
# 167277    2015
# 167278    2015
# 167279    2015
# 167280    2015
# 167281    2015
# 167282    2015
# 167283    2015
# 167284    2015
# 167285    2015
# 167286    2015
# 167287    2015
# 167288    2015
# 167289    2015
# 167290    2015
# 167291    2015
# 167292    2015
# 167293    2015
# 167294    2015
# 167295    2015
#           ...
# 844308    2013
# 844309    2013
# 844310    2013
# 844311    2013
# 844312    2013
# 844313    2013
# 844314    2013
# 844315    2013
# 844316    2013
# 844317    2013
# 844318    2013
# 844319    2013
# 844320    2013
# 844321    2013
# 844322    2013
# 844323    2013
# 844324    2013
# 844325    2013
# 844326    2013
# 844327    2013
# 844328    2013
# 844329    2013
# 844330    2013
# 844331    2013
# 844332    2013
# 844333    2013
# 844334    2013
# ...

# %%
sns.set_style("whitegrid")
fig, axis = plt.subplots(1, 1, figsize=(16, 9))
axis.set_title("daily Sales per year in Feb.")

sns.pointplot(x="day", y="Sales", data=feb.groupby(['year','day'])['Sales'].mean().reset_index(),hue='year', ax=axis)

# %% [markdown]
# ### 探索销售量与假期/促销的关系

# %%
#销售量与假期/促销的关系.因为节假日很多商店关门所以平均销售量明显低于非节假日


fig, (axis1, axis2) = plt.subplots(1, 2, figsize=(16, 9))
fig.suptitle("Effect of Promotion",fontsize =18)
sns.barplot(x = 'Promo', y = 'Sales',data = train_comb,ax=axis1)
sns.boxplot(x = 'Promo', y = 'Sales',data = train_comb, ax=axis2)

fig, (axis1, axis2) = plt.subplots(1, 2, figsize=(16, 9))
fig.suptitle("Effect of Holiday",fontsize =18)
train_comb['StateHoliday'] = train_comb['StateHoliday'].astype(str)
sns.barplot(x = "StateHoliday", y = "Sales",data = train_comb,ax=axis1)
sns.boxplot(x = "StateHoliday", y = "Sales",data = train_comb, ax=axis2)

# %%
# 只参考节假日还营业商店的销售量

fig, (axis1, axis2) = plt.subplots(1, 2, figsize=(16, 9))
fig.suptitle("Effect of Holiday for Open Shops",fontsize =18)


train['StateHoliday'] = train['StateHoliday'].astype(str)

sns.barplot(x = "StateHoliday", y = "Sales",data = train[train['Open']==1],ax=axis1)
sns.boxplot(x = "StateHoliday", y = "Sales",data = train[train['Open']==1], ax=axis2)

# %%
#可以看到只要节假日还在营业的店，销售量和非节假日并没有太大差别
fig, (axis1, axis2) = plt.subplots(1, 2, figsize=(16, 9))

sns.violinplot(x = 'StateHoliday',y = 'Sales',data = train_comb[train_comb.StateHoliday == '0'],ax = axis1)
axis1.set_title('Sales for Non-Holiday')

sns.violinplot(x = 'StateHoliday',y = 'Sales',data = train_comb[(train_comb.StateHoliday !='0')&(train_comb.Open == 1)],ax = axis2)
axis2.set_title('Sales for State Holidays')
# Out:
# Text(0.5,1,'Sales for State Holidays')

# %%
#考察学校假日对销售量的影响,可以看到学校是否放假影响不大

fig, axis = plt.subplots(1, 1, figsize=(16, 9))
axis.set_title("School Holiday")
sns.boxplot(x = 'SchoolHoliday',y = 'Sales',data = train_comb)

# %% [markdown]
# ### 药店类型的影响

# %%
#storetype和assortment均为b的商店销量高一些

fig, (axis1, axis2) = plt.subplots(1, 2, figsize=(16, 9))
fig.suptitle("Effect of Store Type and Assortment",fontsize =18)
sns.barplot(x = 'StoreType', y = 'Sales',data = train_comb,ax=axis1)
sns.barplot(x = 'Assortment', y = 'Sales',data = train_comb, ax=axis2)

# %% [markdown]
# ### 探索竞争者与销量的关系

# %%
#竞争者平均距离与每个店平均销量的关系，采用回归
#这个图如何解读？同样销售量下，竞争者距离越近，能够达到这一销量的药店数量越多
fig, axis = plt.subplots(1, 1, figsize=(16, 9))
axis.set_title("Competition Distance effect on Sales")

sns.regplot(x = 'CompetitionDistance',y = 'Sales',data = train_comb.groupby('Store')['CompetitionDistance','Sales'].agg({'CompetitionDistance':'mean','Sales':'mean'}))

# %% [markdown]
# ### 特征值之间的相关性

# %%
#对 DayOfWeek 以及 StateHoliday 做 One-hot编码

train = pd.get_dummies(train,columns=['DayOfWeek','StateHoliday'])

#相关性矩阵
correlation = train.corr()
fig, axis = plt.subplots(1, 1, figsize=(16, 9))
axis.set_title("Feature Correlation Heatmap")
sns.heatmap(correlation,square = True)

# %%
#上面的热力图可以看到销量与顾客数，高度相关，符合逻辑
#用散点图绘制二者之间的关系

plt.scatter(train_comb.Customers,train_comb.Sales, c = train_comb['DayOfWeek'],alpha =0.8)

plt.xlabel('Customers')
plt.ylabel('Sales')
# Out:
# Text(0,0.5,'Sales')
